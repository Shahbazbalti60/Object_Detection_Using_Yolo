# %%
# %cd /content/ss
# Out:
# /content/ss

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Out:
# Archive:  /content/Football_dectection.v1i.yolov8.zip
#   inflating: README.dataset.txt
#   inflating: README.roboflow.txt
#   inflating: data.yaml
#    creating: train/
#    creating: train/images/
#  extracting: train/images/youtube-37_jpg.rf.16a01a31e01d628923922d22c5c6d364.jpg
#    creating: train/labels/
#   inflating: train/labels/youtube-37_jpg.rf.16a01a31e01d628923922d22c5c6d364.txt

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 14.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 42.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 25.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 49.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 39.9 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# Load a COCO-pretrained YOLO12s model
model = YOLO("yolo11n.pt")

# %%
# %cd /content/drive/MyDrive/Objects Detection using YOLO/data
# Out:
# /content/drive/MyDrive/Objects Detection using YOLO/data

# %%
# Train the model on the COCO8 example dataset for 100 epochs
results = model.train(data="/content/drive/MyDrive/Objects Detection using YOLO/data/data.yaml", epochs=150, imgsz=640, name='GIKI_Object_Detection')
# Out:
# Ultralytics 8.3.176 🚀 Python-3.11.13 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# ...

# %% [markdown]
# #### Inference on image

# %%
# Function for inference on a single image

def infer_image(image_path, output_path="output_image.jpg"):
    # Read the image
    img = cv2.imread(image_path)
    if img is None:
        print(f"Error: Could not load image at {image_path}")
        return

    # Perform inference
    results = model(img)

    # Draw bounding boxes and labels on the image
    annotated_img = results[0].plot()

    # Save the output image
    # cv2.imwrite(output_path, annotated_img)
    cv2_imshow(annotated_img)
    print(f"Output image saved at {output_path}")

# %%
image_path = "/content/drive/MyDrive/Objects Detection using YOLO/data/train/images/frame_0006_jpg.rf.b01e03e635c5e3718d39d9ff7b923cbe.jpg"

# %%
# Run inference on image
infer_image(image_path, "output_image.jpg")
# Out:
# 0: 640x640 1 Street light, 1 Tree, 241.0ms
# Speed: 4.0ms preprocess, 241.0ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=640x640>
# Output image saved at output_image.jpg

# %% [markdown]
# ### Inferencing on video

# %%
# Function for inference on a video
def infer_video(video_path, output_path="output_video.mp4"):
    # Open the video file
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"Error: Could not open video at {video_path}")
        return

    # Get video properties
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))

    # Define the codec and create VideoWriter object
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

    # Process video frame by frame
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # Perform inference on the frame
        results = model(frame)

        # Draw bounding boxes and labels on the frame
        annotated_frame = results[0].plot()

        # Write the frame to the output video
        out.write(annotated_frame)

    # Release resources
    cap.release()
    out.release()
    cv2.destroyAllWindows()
    print(f"Output video saved at {output_path}")

# %%
# Run inference on image
video_path = "/content/drive/MyDrive/Objects Detection using YOLO/detectttt.mp4"

# %%
# Run inference on video
infer_video(video_path, "output_video.mp4")
# Out:
# 0: 640x384 1 Street light, 1 Tree, 153.1ms
# Speed: 7.3ms preprocess, 153.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Street light, 1 Tree, 132.6ms
# Speed: 3.5ms preprocess, 132.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Street light, 1 Tree, 127.9ms
# Speed: 3.9ms preprocess, 127.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Street light, 1 Tree, 125.4ms
# Speed: 3.9ms preprocess, 125.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Street light, 1 Tree, 127.6ms
# Speed: 3.8ms preprocess, 127.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Street light, 1 Tree, 141.6ms
# Speed: 4.4ms preprocess, 141.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Street light, 1 Tree, 126.5ms
# ...

# %%
import cv2
import os

# === CONFIGURATION ===
video_path = '/content/drive/MyDrive/Objects Detection using YOLO/detectttt.mp4'  # ← Change this to your video file path
output_dir = '/content/drive/MyDrive/Objects Detection using YOLO/frame'  # Folder where frames will be saved
frame_interval = 15             # Save every 10th frame
resize_width = 640              # Resize width (adjust as needed)
resize_height = 480             # Resize height (adjust as needed)

# === PREPARE OUTPUT FOLDER ===
os.makedirs(output_dir, exist_ok=True)

# === LOAD VIDEO ===
cap = cv2.VideoCapture(video_path)
frame_count = 0
saved_count = 0

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    if frame_count % frame_interval == 0:
        # Resize frame (optional)
        resized_frame = cv2.resize(frame, (resize_width, resize_height))

        # Save frame
        filename = f"frame_{saved_count:04d}.jpg"
        cv2.imwrite(os.path.join(output_dir, filename), resized_frame)
        print(f"[✓] Saved: {filename}")
        saved_count += 1

    frame_count += 1

cap.release()
print(f"\n✅ Done! Extracted {saved_count} frames into '{output_dir}' folder.")
# Out:
# [✓] Saved: frame_0000.jpg
# [✓] Saved: frame_0001.jpg
# [✓] Saved: frame_0002.jpg
# [✓] Saved: frame_0003.jpg
# [✓] Saved: frame_0004.jpg
# [✓] Saved: frame_0005.jpg
# [✓] Saved: frame_0006.jpg
# [✓] Saved: frame_0007.jpg
# [✓] Saved: frame_0008.jpg
# [✓] Saved: frame_0009.jpg
# [✓] Saved: frame_0010.jpg
# [✓] Saved: frame_0011.jpg
# [✓] Saved: frame_0012.jpg
# [✓] Saved: frame_0013.jpg
# [✓] Saved: frame_0014.jpg
# [✓] Saved: frame_0015.jpg
# [✓] Saved: frame_0016.jpg
# [✓] Saved: frame_0017.jpg
# [✓] Saved: frame_0018.jpg
# [✓] Saved: frame_0019.jpg
# [✓] Saved: frame_0020.jpg
# [✓] Saved: frame_0021.jpg
# [✓] Saved: frame_0022.jpg
# [✓] Saved: frame_0023.jpg
# [✓] Saved: frame_0024.jpg
# [✓] Saved: frame_0025.jpg
# [✓] Saved: frame_0026.jpg
# [✓] Saved: frame_0027.jpg
# [✓] Saved: frame_0028.jpg
# [✓] Saved: frame_0029.jpg
# [✓] Saved: frame_0030.jpg
# [✓] Saved: frame_0031.jpg
# [✓] Saved: frame_0032.jpg
# [✓] Saved: frame_0033.jpg
# [✓] Saved: frame_0034.jpg
# ...

# %% [markdown]
# ### Next
#
# Task:
